# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
# import random
import re
import json
# import scrapy
import numpy as np

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a3b8a10d4a9e37a78f033ef4a4f525f5.css" integrity="sha512-pWLt6abkYhNeAHaDrPVG0yXCtIGRuCkwSUqQpsyN6smAIpIt+Iuq2IZKmoH9l3Cy/9ZnjvVrFZnvFFjGiqE3EA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
tags = ['h2']
text = [element.text for element in soup.find_all(tags)]
texto=[i.replace("\n","").replace(" ","") for i in text]
a=[re.sub("\(", ' (', i) for i in texto]
a
# Out:
# ['pomber (RodrigoPombo)',
#  'kleampa (DragoiCiprian)',
#  'rsms (Rasmus)',
#  'NVlabs (NVIDIAResearchProjects)',
#  'toddmotto (ToddMotto)',
#  'facebook (Facebook)',
#  'The-Art-of-Hacking (ArtofHacking)',
#  'labs42io (Labs42)',
#  'Microsoft (Microsoft)',
#  'isacikgoz (IbrahimSerdarAcikgoz)',
#  'google (Google)',
#  'laravel (TheLaravelPHPFramework)',
#  'gto76 (JureŠorn)',
#  'nextapps-de (NextappsGmbH)',
#  'diegohaz (Haz)',
#  'kentcdodds (KentC.Dodds)',
#  'vuejs (vuejs)',
#  'symfony (Symfony)',
#  'sindresorhus (SindreSorhus)',
#  'gaearon (DanAbramov)',
#  'cjbassi (CalebBassi)',
#  'kamranahmedse (KamranAhmed)',
#  'torvalds (LinusTorvalds)',
#  'apexcharts (ApexCharts)',
#  'tensorflow']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
# soup
tags = ['h3']
text = [element.text for element in soup.find_all(tags)]
texto=[i.strip().split("\n")[0] for i in text]
print(texto)
# Out:
# ['rsms / inter', 'NVlabs / stylegan', 'toddmotto / public-apis', 'gto76 / python-cheatsheet', 'NVlabs / ffhq-dataset', 'facebookresearch / XLM', 'modin-project / modin', 'jliljebl / flowblade', 'depthsecurity / armory', 'stanfordnlp / stanfordnlp', 'torfsen / python-systemd-tutorial', 'vietnguyen91 / QuickDraw', 'donnemartin / system-design-primer', 'keras-team / keras', 'vinta / awesome-python', 'rg3 / youtube-dl', 'tensorflow / models', 'ray-project / ray', 'caronc / apprise', 'ansible / ansible', 'bourdakos1 / tfjs-object-detection-training', 'zalandoresearch / flair', 'TheAlgorithms / Python', 'deepfakes / faceswap', 'pallets / flask']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
soup
tags = ['img']
text = [element for element in soup.find_all(tags)]
text_src=[j['src'] for j in text]
# texto=[i.replace("\n","").strip() for i in text]
print(text_src)
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG', '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg', '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_19
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
soup
tags = ['link']
text = [element for element in soup.find_all(tags)]
text_href=[j['href'] for j in text]

# links = []
# for i in soup.findAll('a', attrs={'href': re.compile("^http://")}):
#     print i.append(link.get('href'))

print(text_href)
# Out:
# ['/w/load.php?debug=false&lang=en&modules=ext.3d.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&only=styles&skin=vector', '/w/load.php?debug=false&lang=en&modules=ext.gadget.charinsert-styles&only=styles&skin=vector', '/w/load.php?debug=false&lang=en&modules=site.styles&only=styles&skin=vector', 'android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Python', '/w/index.php?title=Python&action=edit', '/w/index.php?title=Python&action=edit', '/static/apple-touch/wikipedia.png', '/static/favicon/wikipedia.ico', '/w/opensearch_desc.php', '//en.wikipedia.org/w/api.php?action=rsd', '//creativecommons.org/licenses/by-sa/3.0/', 'https://en.wikipedia.org/wiki/Python', '//login.wikimedia.org', '//meta.wikimedia.org']

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
# usctitlechanged
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
soup

text = [element.text for element in soup.find_all('div',{'class':'usctitlechanged'})]
texto=[i.replace("\n","").strip() for i in text]
print(len(texto))
# Out:
# 21

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
html = requests.get(url).content
html[0:600]
soup = BeautifulSoup(html, "lxml")
soup

tags = ['h3']
text = [element.text for element in soup.find_all(tags)]
texto=[i.replace("\n","").strip() for i in text]
print(texto)
# Out:
# ['LAMONT STEPHENSON', 'RAFAEL CARO-QUINTERO', 'ALEXIS FLORES', 'SANTIAGO VILLALBA MEDEROS', 'ROBERT WILLIAM FISHER', 'ALEJANDRO ROSALES CASTILLO', 'GREG ALYN CARLSON', 'YASER ABDEL SAID', 'BHADRESHKUMAR CHETANBHAI PATEL', 'JASON DEREK BROWN']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table=soup.select('table')[3]
values = []
rows = table.select('tr')
for row in rows:
    cells = row.select('td')
    if len(cells) > 3:
        date=re.findall('\d+-\d+-\d+', cells[3].text.strip())
        time=re.findall('\d+:\d+:\d+.\d', cells[3].text.strip())
        values.append([
            date[0],
            time[0],
            cells[4].text.strip() + cells[5].text.strip(),
            cells[6].text.strip() + cells[7].text.strip(),
            cells[11].text.strip()
        ])
    
colnames=['date','time','latitude','longitude','region name']
df = pd.DataFrame(values,columns=colnames)
df.tail(20)
# Out:
#           date        time latitude longitude                      region name
# 30  2019-02-07  04:14:23.2   19.70N    65.69W               PUERTO RICO REGION
# 31  2019-02-07  04:11:57.0   21.28S    68.84W               ANTOFAGASTA, CHILE
# 32  2019-02-07  04:08:27.0   23.02S    66.67W                 JUJUY, ARGENTINA
# 33  2019-02-07  03:27:03.6   19.52N    65.62W               PUERTO RICO REGION
# 34  2019-02-07  03:12:58.0   19.43N    68.12W        DOMINICAN REPUBLIC REGION
# 35  2019-02-07  03:04:01.1   19.50N   155.65W         ISLAND OF HAWAII, HAWAII
# 36  2019-02-07  02:57:10.6   37.43N    20.46E                       IONIAN SEA
# 37  2019-02-07  02:42:13.7   37.60N    20.66E                       IONIAN SEA
# 38  2019-02-07  02:03:53.0    2.20N   128.71E             HALMAHERA, INDONESIA
# 39  2019-02-07  02:02:52.8   42.84N    13.03E                    CENTRAL ITALY
# 40  2019-02-07  01:59:00.0   34.76N    23.52E                    CRETE, GREECE
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table=soup.find_all('div')
#Creo que está capado debido a que esta página está realizada con Angular y habría que usar selenium para poder obtener el <body>

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/marca'

# %%
#your code
try:
    html = requests.get(url).content
    soup = BeautifulSoup(html, "lxml")
    table=soup.find_all('span',{'class':'ProfileNav-value'})
    if table:
        info_tweets=[i.text.strip().split("\n") for i in table]
        tweets=info_tweets[0][0].replace("\xa0"," ")
    else:
        raise Exception('Account not found')
except Exception:
    raise
print(tweets)
# Out:
# 334 mil

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/marca'

# %%
#your code
try:
    html = requests.get(url).content
    soup = BeautifulSoup(html, "lxml")
    table=soup.find_all('span',{'class':'ProfileNav-value'})
    if table:
        info_followers=[i.text.strip().split("\n") for i in table]
        followers=info_followers[2][0].replace("\xa0"," ")
    else:
        raise Exception('Account not found')
except Exception:
    raise
print(followers)
# Out:
# 4,92 M

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table=soup.find_all('div',{'class':'central-featured'})
lang=table[0].select("div")
texto=[i.text.strip().split("\n")[0] for i in lang]
print(texto)
# Out:
# ['English', '日本語', 'Deutsch', 'Русский', 'Español', 'Français', 'Italiano', '中文', 'Português', 'Polski']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table=soup.find_all('h2')
texto=[i.text.strip().split("\n") for i in table]
datasets=[j[0] for j in texto]
print(datasets)
# Out:
# ['Business and economy', 'Crime and justice', 'Defence', 'Education', 'Environment', 'Government', 'Government spending', 'Health', 'Mapping', 'Society', 'Towns and cities', 'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table=soup.find_all('table',{'class':'wikitable'})
values = []
rows = table[0].select('tr')
languages=[i.select('td')[1].select('b')[0].text.strip() for i in rows if len(i.select('td'))>0]
languages.pop()
languages=languages[:10]

print(languages)
# Out:
# ['Mandarin', 'Spanish', 'English', 'Hindi', 'Arabic', 'Portuguese', 'Bengali', 'Russian', 'Japanese', 'Punjabi']

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/marca'

# %%
# your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
# table=soup.find_all('span',{'class':'ProfileNav-value'})
table=soup.find_all('div',{'class':'js-tweet-text-container'})
info_tweets=[i.text.strip().split("\n")[0] for i in table]
print(info_tweets)
# Out:
# ['Pegó primero Lucas. A los seis minutos', 'Keylor Navas, un muro en el Camp Nou https://trib.al/gdC4x3q', 'EN DIRECTO | Últimas horas del periodo de traspasos en la #NBA: Movimientos y situación de los españoles https://www.marca.com/baloncesto/nba/2019/02/07/5c5bd933268e3ec9598b45a6.html\xa0… @MarcGasol, @RickyRubio9, @PauGasol y @Threekola Mirotic podrían cambiar de equipopic.twitter.com/pqcptKLQDM', '#LaLiga corrige el límite salarial y el Atlético tiene 12 millones máshttps://www.marca.com/futbol/primera-division/2019/02/06/5c5ad572ca47419c638b45ea.html\xa0…', "'Entre Messi y Coutinho debe existir un término medio'  https://trib.al/aSOnyH1\xa0 La opinión de @pabloegea", '#CopaDelRey ', '\u200d Lo que no has visto del Clásico: Marcelo de rodillas, las molestias de Messi... https://trib.al/7njLpal\xa0pic.twitter.com/zkFD1vW8yf', 'Este punto de Novikov ya da la vuelta al mundo del tenis... ¡efecto increíble! https://trib.al/Y0rV6b9', 'Vinícius amaga, pero no da https://trib.al/cCip
# ...

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# # your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table=soup.find_all('table')
films=table[0].find_all('a', title=True)
dir_stars=[d_s['title'] for d_s in films]
names=[name.text for name in films]
titlesColumns=table[0].find_all('td',{"class":"titleColumn"})
releases=[release.find_all("span")[0].text for release in titlesColumns]
data=[names,releases,dir_stars]
colnames=['movie name','initial release','director name and stars']
data=np.array(data).T.tolist()
df = pd.DataFrame(data,columns=colnames)
df
# Out:
#                                             movie name initial release  \
# 0                                      Cadena perpetua          (1994)
# 1                                           El padrino          (1972)
# 2                                 El padrino: Parte II          (1974)
# 3                                  El caballero oscuro          (2008)
# 4                                12 hombres sin piedad          (1957)
# 5                                La lista de Schindler          (1993)
# 6          El señor de los anillos: El retorno del rey          (2003)
# 7                                         Pulp Fiction          (1994)
# 8                           El bueno, el feo y el malo          (1966)
# 9                                  El club de la lucha          (1999)
# 10    El señor de los anillos: La comunidad del anillo          (2001)
# 11                                        Forrest Gump          (1994)
# ...

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table=soup.find_all('table')
films=table[0].find_all('a', title=True)
names=[name.text for name in films]
href=[name['href'] for name in films]

titlesColumns=table[0].find_all('td',{"class":"titleColumn"})
releases=[year.find_all("span")[0].text for year in titlesColumns]
url2='http://www.imdb.com/'
summary=[]
for ref in href:
    html = requests.get(url2+ref).content
    soup = BeautifulSoup(html, "lxml")
    table= soup.find_all('div',{'class':'summary_text'})
    summary.append(table[0].text.strip().split("\n"))
summary1=[i[0] for i in summary]

data=[names,releases,summary1]
colnames=['name','year','summary']
data=np.array(data).T.tolist()
df = pd.DataFrame(data,columns=colnames)
df.sample(10)
# Out:
#                           name    year  \
# 197                    Ben-Hur  (1959)
# 158     No es país para viejos  (2007)
# 208                Prisioneros  (2013)
# 156            Fresas salvajes  (1957)
# 97         Matar a un ruiseñor  (1962)
# 213         Atrápame si puedes  (2002)
# 147     Del revés (Inside Out)  (2015)
# 91                   Perdición  (1944)
# 179  Cómo entrenar a tu dragón  (2010)
# 187     El gran hotel Budapest  (2014)
#
#                                                summary
# 197  When a Jewish prince is betrayed and sent into...
# 158  Violence and mayhem ensue after a hunter stumb...
# 208  When Keller Dover's daughter and her friend go...
# 156  After living a life marked by coldness, an agi...
# 97   Atticus Finch, a lawyer in the Depression-era ...
# 213  A seasoned FBI agent pursues Frank Abagnale Jr...
# 147  After young Riley is uprooted from her Midwest...
# 91   An insurance representative lets himself be ta...
# ...

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city:Madrid

# %%
# your code

url_2 = urlopen(url)
content = url_2.read()
soup = BeautifulSoup(content)
report = soup.select('p')
a=[x for x in report[0]]
newDictionary=json.loads(str(a[0]))
lista=[lang[0] for lang in newDictionary]
values={"Temperature":newDictionary['main']['temp'],"Wind Speed":newDictionary['wind']['speed'],"Description":newDictionary['weather'][0]['description'],"Weather":newDictionary['weather']}
print(city+"\n{}".format(values))
# Out:
# Madrid
# {'Temperature': 7.8, 'Wind Speed': 1, 'Description': 'clear sky', 'Weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table=soup.find_all('article',{'class':'product_pod'})
names=[product.find_all('h3')[0].text for product in table]
prices=[price.find_all('p',{'class':'price_color'})[0].text for price in table]
stock=[stock.find_all('p',{'class':'instock availability'})[0].text.strip().split("\n")[0] for stock in table]
data=[names,prices,stock]
colnames=['name','price','stock availability']
data=np.array(data).T.tolist()
df = pd.DataFrame(data,columns=colnames)
df
# Out:
#                                      name   price stock availability
# 0                      A Light in the ...  £51.77           In stock
# 1                      Tipping the Velvet  £53.74           In stock
# 2                              Soumission  £50.10           In stock
# 3                           Sharp Objects  £47.82           In stock
# 4            Sapiens: A Brief History ...  £54.23           In stock
# 5                         The Requiem Red  £22.65           In stock
# 6            The Dirty Little Secrets ...  £33.34           In stock
# 7                 The Coming Woman: A ...  £17.93           In stock
# 8                     The Boys in the ...  £22.60           In stock
# 9                         The Black Maria  £52.15           In stock
# 10  Starving Hearts (Triangular Trade ...  £13.99           In stock
# 11                  Shakespeare's Sonnets  £20.66           In stock
# 12                            Set Me Free  £17.46           In stock
# ...
